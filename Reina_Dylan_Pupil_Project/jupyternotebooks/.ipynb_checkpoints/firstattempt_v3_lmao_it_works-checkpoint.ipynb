# %% [markdown]
# Loading in Pupil Data

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import os

# %%
# #old one file way
# data_file = '../data/POJMI4.csv'
# colnames =["subject","unknown", "nums", "xcoor", "ycoor", "pupsize", "timing", "trial","experiment", "tone1", "tone2", "condition", "image", "one", "dot1", "dot2", "dot3", "trialfalse", "NOCLICK", "noclick"]
# df_podcdat = pd.read_csv(data_file, names=colnames)

# %%
#new loop through all files
data_folder = '../data/'
os.listdir(data_folder)
pup_files = sorted([f for f in os.listdir(data_folder) if ('PO' in f) and ('.csv' in f)])

colnames =["subject","unknown", "nums", "xcoor", "ycoor", "pupsize", "timing", "trial","experiment", "tone1", "tone2", "condition", "image", "one", "dot1", "dot2", "dot3", "trialfalse", "NOCLICK", "noclick"]
for a in range(len(pup_files)):
    participant= data_folder+pup_files[a]
    df_podcdat = pd.read_csv(participant, names=colnames)
    #put timing column into list to make easier to work with pandas
    timing = df_podcdat.timing.tolist()
    pupsize = df_podcdat.pupsize.tolist()
    new_timing=[]
    for b in range(len(timing)):#Start from begining to end of timing list
        num = timing[b]#set num = to timing at specific location in list
        if num%2 !=0:# if number divided by 2 has a remainder that is not 0
            num = num + 1 # take that number with the nonzero remainder and add one to it
            new_timing.append(num)# take the new number and append it to the new_timing list
        else:# if the number is even
            new_timing.append(num)# take the even number and append it to the new_timing list
    new_timing = pd.DataFrame(new_timing)
    result = pd.concat([df_podcdat, new_timing], axis=1)
    result = result.rename(columns = {0:'newtiming'})
    pup_zeros=[]
    for c in range(len(pupsize)):#Start from begining to end of pupsize list
        num = pupsize[c]#set num = to pupsize at specific location in list, index?
        if num == 0:# if number is 0
            pup_zeros.append(c)# take the index location and append it to the pup_zeros list
    pup_array=np.asarray(pupsize)
    pz = pd.DataFrame(pup_zeros)
    pup_all = pd.DataFrame().reindex_like(pz)
    before = pd.DataFrame().reindex_like(pz)
    after = pd.DataFrame().reindex_like(pz)


    pup_all = pup_all.rename(columns = {0:'original'})
    before = before.rename(columns = {0:'before'})
    after = after.rename(columns = {0:'after'})
    pup_all = pd.concat([pup_all, before, after],axis=1)

    for d in range(len(pup_zeros)):
        pup_all.original[d] = pup_zeros[d]
        pup_all.before[d] = pup_zeros[d] - 75
        pup_all.after[d] = pup_zeros[d] + 75


    #group by sequence
    #take list value by value find one not a number in sequence pull and store index of 150 samples before vlaue 
    #then if next not is only one greater then last one if it is greater make that a new one 

    #interp 1.2 - RM suggestion convert this into using df.apply()
    #works!!!! but now lets see if it is actually doing what i think it is doing 
    for e in range(len(result)):
        if result.pupsize[e]==0:
            before=e-75
            after=e+75
            result.pupsize.ix[before:after] = np.nan

    print("done")

    result['interp_pupsize'] = result.pupsize.interpolate()#(method='spline', order=2) #figuring out how we want to interp

    subsetres = result.loc[(result["newtiming"]==4500),:]
    forbaseline = subsetres[['interp_pupsize','trial']]
    forbaseline = forbaseline.reset_index()
    forbaseline = forbaseline.rename(index=str, columns={"interp_pupsize": "baseval"})
    result = forbaseline.merge(result, on = 'trial', how = 'right')

    result['bvaled'] = 0
    result['bvaled'] = (result.interp_pupsize - result.baseval)
    result.head()
    new='new.csv'
    result.to_csv(pup_files[a]+new)
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# done
# done
# done

# %% [markdown]
# Making new timing column of even numbers

# %%
#THis works for one file
# new='new.csv'
# pup_files[0]

# pd.DataFrame()
# result.to_csv(pup_files[0]+new)

# %%
counter = 0;

# %%
a = 'k'
counter = counter+1;
a = a+str(counter);
a = pd.DataFrame(result)

whos
# Out:
#          index  baseval  trial     subject  unknown     nums  xcoor  ycoor  \
# 0         2249   526.00      1  POJMI4.asc  unknown  7232610  619.2  535.2
# 1         2249   526.00      1  POJMI4.asc  unknown  7232612  619.2    535
# 2         2249   526.00      1  POJMI4.asc  unknown  7232614  619.2  534.8
# 3         2249   526.00      1  POJMI4.asc  unknown  7232616  619.2  534.8
# 4         2249   526.00      1  POJMI4.asc  unknown  7232618  619.2  535.1
# 5         2249   526.00      1  POJMI4.asc  unknown  7232620  619.1  535.5
# 6         2249   526.00      1  POJMI4.asc  unknown  7232622    619  535.8
# 7         2249   526.00      1  POJMI4.asc  unknown  7232624  618.9    536
# 8         2249   526.00      1  POJMI4.asc  unknown  7232626  618.7  535.8
# 9         2249   526.00      1  POJMI4.asc  unknown  7232628  618.5  535.6
# 10        2249   526.00      1  POJMI4.asc  unknown  7232630  618.2  534.7
# 11        2249   526.00      1  POJMI4.asc  unknown  7232632  617.7  533.7
# 12        2249   526.00      1  POJMI4.asc  unknown  7232634  617.1  532.6
# 13        2249   526.00      1  POJMI4.asc  unknown  7232636  616.6  531.6
# 14        2249   526.00      1  POJMI4.asc  unknown  7232638  616.2  530.7
# 15        2249   526.00      1  POJMI4.asc  unknown  7232640  615.9  530.3
# 16        2249   526.00      1  POJMI4.asc  unknown  7232642  615.7  530.1
# 17        2249   526.00      1  POJMI4.asc  unknown  7232644  615.7  530.5
# 18        2249   526.00      1  POJMI4.asc  unknown  7232646    616  530.9
# 19        2249   526.00      1  POJMI4.asc  unknown  7232648  616.5  531.4
# 20        2249   526.00      1  POJMI4.asc  unknown  7232650  617.1    532
# 21        2249   526.00      1  POJMI4.asc  unknown  7232652  617.8  532.6
# 22        2249   526.00      1  POJMI4.asc  unknown  7232654  618.6  533.1
# 23        2249   526.00      1  POJMI4.asc  unknown  7232656  619.5  533.2
# 24        2249   526.00      1  POJMI4.asc  unknown  7232658  621.3  533.3
# 25        2249   526.00      1  POJMI4.asc  unknown  7232660    623  532.9
# 26        2249   526.00      1  POJMI4.asc  unknown  7232662  624.7  532.6
# 27        2249   526.00      1  POJMI4.asc  unknown  7232664  626.1  532.1
# 28        2249   526.00      1  POJMI4.asc  unknown  7232666  627.5  531.7
# 29        2249   526.00      1  POJMI4.asc  unknown  7232668  628.6  531.3
# ...        ...      ...    ...         ...      ...      ...    ...    ...
# 133526  131632   291.75     32  POJMI4.asc  unknown  7570604  664.5  495.6
# 133527  131632   291.75     32  POJMI4.asc  unknown  7570606    664  496.7
# 133528  131632   291.75     32  POJMI4.asc  unknown  7570608  663.1  498.2
# 133529  131632   291.75     32  POJMI4.asc  unknown  7570610  662.4  499.3
# 133530  131632   291.75     32  POJMI4.asc  unknown  7570612  661.8  500.1
# 133531  131632   291.75     32  POJMI4.asc  unknown  7570614  661.4  499.7
# 133532  131632   291.75     32  POJMI4.asc  unknown  7570616  661.1  499.3
# 133533  131632   291.75     32  POJMI4.asc  unknown  7570618  661.1  498.8
# 133534  131632   291.75     32  POJMI4.asc  unknown  7570620  661.1  497.6
# 133535  131632   291.75     32  POJMI4.asc  unknown  7570622  661.5  496.4
# 133536  131632   291.75     32  POJMI4.asc  unknown  7570624  661.7  495.4
# 133537  131632   291.75     32  POJMI4.asc  unknown  7570626  661.7  494.3
# 133538  131632   291.75     32  POJMI4.asc  unknown  7570628  661.2  493.4
# 133539  131632   291.75     32  POJMI4.asc  unknown  7570630  660.6  492.5
# 133540  131632   291.75     32  POJMI4.asc  unknown  7570632  659.9  491.7
# 133541  131632   291.75     32  POJMI4.asc  unknown  7570634  659.2  491.7
# 133542  131632   291.75     32  POJMI4.asc  unknown  7570636  658.4  491.9
# 133543  131632   291.75     32  POJMI4.asc  unknown  7570638  657.7  492.1
# 133544  131632   291.75     32  POJMI4.asc  unknown  7570640  657.1  492.4
# 133545  131632   291.75     32  POJMI4.asc  unknown  7570642  657.1  492.8
# 133546  131632   291.75     32  POJMI4.asc  unknown  7570644  657.5  493.2
# 133547  131632   291.75     32  POJMI4.asc  unknown  7570646    658  494.1
# 133548  131632   291.75     32  POJMI4.asc  unknown  7570648  658.5    495
# 133549  131632   291.75     32  POJMI4.asc  unknown  7570650  659.1  497.6
# 133550  131632   291.75     32  POJMI4.asc  unknown  7570652  659.9  500.1
# 133551  131632   291.75     32  POJMI4.asc  unknown  7570654  660.5  502.4
# 133552  131632   291.75     32  POJMI4.asc  unknown  7570656  661.2  504.4
# 133553  131632   291.75     32  POJMI4.asc  unknown  7570658  661.9  506.1
# 133554  131632   291.75     32  POJMI4.asc  unknown  7570660  662.6  507.5
# 133555  131632   291.75     32  POJMI4.asc  unknown  7570662  663.5  508.4
#
#         pupsize  timing   ...   one dot1 dot2 dot3 trialfalse  NOCLICK  \
# 0         710.0       1   ...     1    .    .    .     trial2  NOCLICK
# 1         710.0       3   ...     1    .    .    .     trial2  NOCLICK
# 2         710.0       5   ...     1    .    .    .     trial2  NOCLICK
# 3         710.0       7   ...     1    .    .    .     trial2  NOCLICK
# 4         710.0       9   ...     1    .    .    .     trial2  NOCLICK
# 5         710.0      11   ...     1    .    .    .     trial2  NOCLICK
# 6         710.0      13   ...     1    .    .    .     trial2  NOCLICK
# 7         709.0      15   ...     1    .    .    .     trial2  NOCLICK
# 8         709.0      17   ...     1    .    .    .     trial2  NOCLICK
# 9         709.0      19   ...     1    .    .    .     trial2  NOCLICK
# 10        709.0      21   ...     1    .    .    .     trial2  NOCLICK
# 11        710.0      23   ...     1    .    .    .     trial2  NOCLICK
# 12        710.0      25   ...     1    .    .    .     trial2  NOCLICK
# 13        710.0      27   ...     1    .    .    .     trial2  NOCLICK
# 14        711.0      29   ...     1    .    .    .     trial2  NOCLICK
# 15        711.0      31   ...     1    .    .    .     trial2  NOCLICK
# 16        711.0      33   ...     1    .    .    .     trial2  NOCLICK
# 17        711.0      35   ...     1    .    .    .     trial2  NOCLICK
# 18        711.0      37   ...     1    .    .    .     trial2  NOCLICK
# 19        711.0      39   ...     1    .    .    .     trial2  NOCLICK
# 20        711.0      41   ...     1    .    .    .     trial2  NOCLICK
# 21        711.0      43   ...     1    .    .    .     trial2  NOCLICK
# 22        711.0      45   ...     1    .    .    .     trial2  NOCLICK
# 23        711.0      47   ...     1    .    .    .     trial2  NOCLICK
# 24        711.0      49   ...     1    .    .    .     trial2  NOCLICK
# 25        710.0      51   ...     1    .    .    .     trial2  NOCLICK
# 26        710.0      53   ...     1    .    .    .     trial2  NOCLICK
# 27        710.0      55   ...     1    .    .    .     trial2  NOCLICK
# 28        710.0      57   ...     1    .    .    .     trial2  NOCLICK
# 29        710.0      59   ...     1    .    .    .     trial2  NOCLICK
# ...         ...     ...   ...    ..  ...  ...  ...        ...      ...
# 133526    294.0    8288   ...     1    .    .    .    trial31  NOCLICK
# 133527    294.0    8290   ...     1    .    .    .    trial31  NOCLICK
# 133528    294.0    8292   ...     1    .    .    .    trial31  NOCLICK
# 133529    295.0    8294   ...     1    .    .    .    trial31  NOCLICK
# 133530    295.0    8296   ...     1    .    .    .    trial31  NOCLICK
# 133531    295.0    8298   ...     1    .    .    .    trial31  NOCLICK
# 133532    295.0    8300   ...     1    .    .    .    trial31  NOCLICK
# 133533    295.0    8302   ...     1    .    .    .    trial31  NOCLICK
# 133534    295.0    8304   ...     1    .    .    .    trial31  NOCLICK
# 133535    295.0    8306   ...     1    .    .    .    trial31  NOCLICK
# 133536    295.0    8308   ...     1    .    .    .    trial31  NOCLICK
# 133537    295.0    8310   ...     1    .    .    .    trial31  NOCLICK
# 133538    295.0    8312   ...     1    .    .    .    trial31  NOCLICK
# 133539    295.0    8314   ...     1    .    .    .    trial31  NOCLICK
# 133540    295.0    8316   ...     1    .    .    .    trial31  NOCLICK
# 133541    295.0    8318   ...     1    .    .    .    trial31  NOCLICK
# 133542    295.0    8320   ...     1    .    .    .    trial31  NOCLICK
# 133543    295.0    8322   ...     1    .    .    .    trial31  NOCLICK
# 133544    295.0    8324   ...     1    .    .    .    trial31  NOCLICK
# 133545    295.0    8326   ...     1    .    .    .    trial31  NOCLICK
# 133546    296.0    8328   ...     1    .    .    .    trial31  NOCLICK
# 133547    296.0    8330   ...     1    .    .    .    trial31  NOCLICK
# 133548    296.0    8332   ...     1    .    .    .    trial31  NOCLICK
# 133549    297.0    8334   ...     1    .    .    .    trial31  NOCLICK
# 133550    298.0    8336   ...     1    .    .    .    trial31  NOCLICK
# 133551    298.0    8338   ...     1    .    .    .    trial31  NOCLICK
# 133552    299.0    8340   ...     1    .    .    .    trial31  NOCLICK
# 133553    299.0    8342   ...     1    .    .    .    trial31  NOCLICK
# 133554    299.0    8344   ...     1    .    .    .    trial31  NOCLICK
# 133555    299.0    8346   ...     1    .    .    .    trial31  NOCLICK
#
#         noclick newtiming interp_pupsize  bvaled
# 0       noclick         2          710.0  184.00
# 1       noclick         4          710.0  184.00
# 2       noclick         6          710.0  184.00
# 3       noclick         8          710.0  184.00
# 4       noclick        10          710.0  184.00
# 5       noclick        12          710.0  184.00
# 6       noclick        14          710.0  184.00
# 7       noclick        16          709.0  183.00
# 8       noclick        18          709.0  183.00
# 9       noclick        20          709.0  183.00
# 10      noclick        22          709.0  183.00
# 11      noclick        24          710.0  184.00
# 12      noclick        26          710.0  184.00
# 13      noclick        28          710.0  184.00
# 14      noclick        30          711.0  185.00
# 15      noclick        32          711.0  185.00
# 16      noclick        34          711.0  185.00
# 17      noclick        36          711.0  185.00
# 18      noclick        38          711.0  185.00
# 19      noclick        40          711.0  185.00
# 20      noclick        42          711.0  185.00
# 21      noclick        44          711.0  185.00
# 22      noclick        46          711.0  185.00
# 23      noclick        48          711.0  185.00
# 24      noclick        50          711.0  185.00
# 25      noclick        52          710.0  184.00
# 26      noclick        54          710.0  184.00
# 27      noclick        56          710.0  184.00
# 28      noclick        58          710.0  184.00
# 29      noclick        60          710.0  184.00
# ...         ...       ...            ...     ...
# 133526  noclick      8288          294.0    2.25
# 133527  noclick      8290          294.0    2.25
# 133528  noclick      8292          294.0    2.25
# 133529  noclick      8294          295.0    3.25
# 133530  noclick      8296          295.0    3.25
# 133531  noclick      8298          295.0    3.25
# 133532  noclick      8300          295.0    3.25
# 133533  noclick      8302          295.0    3.25
# 133534  noclick      8304          295.0    3.25
# 133535  noclick      8306          295.0    3.25
# 133536  noclick      8308          295.0    3.25
# 133537  noclick      8310          295.0    3.25
# 133538  noclick      8312          295.0    3.25
# 133539  noclick      8314          295.0    3.25
# 133540  noclick      8316          295.0    3.25
# 133541  noclick      8318          295.0    3.25
# 133542  noclick      8320          295.0    3.25
# 133543  noclick      8322          295.0    3.25
# 133544  noclick      8324          295.0    3.25
# 133545  noclick      8326          295.0    3.25
# 133546  noclick      8328          296.0    4.25
# 133547  noclick      8330          296.0    4.25
# 133548  noclick      8332          296.0    4.25
# 133549  noclick      8334          297.0    5.25
# 133550  noclick      8336          298.0    6.25
# 133551  noclick      8338          298.0    6.25
# 133552  noclick      8340          299.0    7.25
# 133553  noclick      8342          299.0    7.25
# 133554  noclick      8344          299.0    7.25
# 133555  noclick      8346          299.0    7.25
#
# [133556 rows x 25 columns]

# %%
whos
# Out:
# Variable      Type         Data/Info
# ------------------------------------
# a             DataFrame             index  baseval  <...>133556 rows x 25 columns]
# after         int          131802
# before        int          131652
# colnames      list         n=20
# counter       int          12
# data_folder   str          ../data/
# df_podcdat    DataFrame               subject  unkno<...>133556 rows x 20 columns]
# forbaseline   DataFrame         index  baseval  tria<...>1  131632   291.75     32
# i             int          133555
# new           str          new.csv
# new_timing    DataFrame               0\n0          <...>[133556 rows x 1 columns]
# np            module       <module 'numpy' from '/Ap<...>kages/numpy/__init__.py'>
# num           int          299
# os            module       <module 'os' from '/Appli<...>nda/lib/python3.6/os.py'>
# participant   str          ../data/POJMI4.csv
# pd            module       <module 'pandas' from '/A<...>ages/pandas/__init__.py'>
# plt           module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# pup_all       DataFrame          original    before <...>\n[3623 rows x 3 columns]
# pup_array     ndarray      133556: 133556 elems, type `int64`, 1068448 bytes (1.018951416015625 Mb)
# pup_files     list         n=3
# pup_zeros     list         n=3623
# pupsize       list         n=133556
# pz            DataFrame               0\n0        45<...>\n[3623 rows x 1 columns]
# result        DataFrame             index  baseval  <...>133556 rows x 25 columns]
# subsetres     DataFrame               subject  unkno<...>n\n[32 rows x 22 columns]
# timing        list         n=133556

# %%
os.makedir
result.to_csv()

# %%
a
# Out:
#          index  baseval  trial     subject  unknown     nums  xcoor  ycoor  \
# 0         2249   526.00      1  POJMI4.asc  unknown  7232610  619.2  535.2
# 1         2249   526.00      1  POJMI4.asc  unknown  7232612  619.2    535
# 2         2249   526.00      1  POJMI4.asc  unknown  7232614  619.2  534.8
# 3         2249   526.00      1  POJMI4.asc  unknown  7232616  619.2  534.8
# 4         2249   526.00      1  POJMI4.asc  unknown  7232618  619.2  535.1
# 5         2249   526.00      1  POJMI4.asc  unknown  7232620  619.1  535.5
# 6         2249   526.00      1  POJMI4.asc  unknown  7232622    619  535.8
# 7         2249   526.00      1  POJMI4.asc  unknown  7232624  618.9    536
# 8         2249   526.00      1  POJMI4.asc  unknown  7232626  618.7  535.8
# 9         2249   526.00      1  POJMI4.asc  unknown  7232628  618.5  535.6
# 10        2249   526.00      1  POJMI4.asc  unknown  7232630  618.2  534.7
# 11        2249   526.00      1  POJMI4.asc  unknown  7232632  617.7  533.7
# 12        2249   526.00      1  POJMI4.asc  unknown  7232634  617.1  532.6
# 13        2249   526.00      1  POJMI4.asc  unknown  7232636  616.6  531.6
# 14        2249   526.00      1  POJMI4.asc  unknown  7232638  616.2  530.7
# 15        2249   526.00      1  POJMI4.asc  unknown  7232640  615.9  530.3
# 16        2249   526.00      1  POJMI4.asc  unknown  7232642  615.7  530.1
# 17        2249   526.00      1  POJMI4.asc  unknown  7232644  615.7  530.5
# 18        2249   526.00      1  POJMI4.asc  unknown  7232646    616  530.9
# 19        2249   526.00      1  POJMI4.asc  unknown  7232648  616.5  531.4
# 20        2249   526.00      1  POJMI4.asc  unknown  7232650  617.1    532
# 21        2249   526.00      1  POJMI4.asc  unknown  7232652  617.8  532.6
# 22        2249   526.00      1  POJMI4.asc  unknown  7232654  618.6  533.1
# 23        2249   526.00      1  POJMI4.asc  unknown  7232656  619.5  533.2
# 24        2249   526.00      1  POJMI4.asc  unknown  7232658  621.3  533.3
# 25        2249   526.00      1  POJMI4.asc  unknown  7232660    623  532.9
# 26        2249   526.00      1  POJMI4.asc  unknown  7232662  624.7  532.6
# 27        2249   526.00      1  POJMI4.asc  unknown  7232664  626.1  532.1
# 28        2249   526.00      1  POJMI4.asc  unknown  7232666  627.5  531.7
# 29        2249   526.00      1  POJMI4.asc  unknown  7232668  628.6  531.3
# ...        ...      ...    ...         ...      ...      ...    ...    ...
# 133526  131632   291.75     32  POJMI4.asc  unknown  7570604  664.5  495.6
# 133527  131632   291.75     32  POJMI4.asc  unknown  7570606    664  496.7
# 133528  131632   291.75     32  POJMI4.asc  unknown  7570608  663.1  498.2
# 133529  131632   291.75     32  POJMI4.asc  unknown  7570610  662.4  499.3
# 133530  131632   291.75     32  POJMI4.asc  unknown  7570612  661.8  500.1
# 133531  131632   291.75     32  POJMI4.asc  unknown  7570614  661.4  499.7
# 133532  131632   291.75     32  POJMI4.asc  unknown  7570616  661.1  499.3
# 133533  131632   291.75     32  POJMI4.asc  unknown  7570618  661.1  498.8
# 133534  131632   291.75     32  POJMI4.asc  unknown  7570620  661.1  497.6
# 133535  131632   291.75     32  POJMI4.asc  unknown  7570622  661.5  496.4
# 133536  131632   291.75     32  POJMI4.asc  unknown  7570624  661.7  495.4
# 133537  131632   291.75     32  POJMI4.asc  unknown  7570626  661.7  494.3
# 133538  131632   291.75     32  POJMI4.asc  unknown  7570628  661.2  493.4
# 133539  131632   291.75     32  POJMI4.asc  unknown  7570630  660.6  492.5
# 133540  131632   291.75     32  POJMI4.asc  unknown  7570632  659.9  491.7
# 133541  131632   291.75     32  POJMI4.asc  unknown  7570634  659.2  491.7
# 133542  131632   291.75     32  POJMI4.asc  unknown  7570636  658.4  491.9
# 133543  131632   291.75     32  POJMI4.asc  unknown  7570638  657.7  492.1
# 133544  131632   291.75     32  POJMI4.asc  unknown  7570640  657.1  492.4
# 133545  131632   291.75     32  POJMI4.asc  unknown  7570642  657.1  492.8
# 133546  131632   291.75     32  POJMI4.asc  unknown  7570644  657.5  493.2
# 133547  131632   291.75     32  POJMI4.asc  unknown  7570646    658  494.1
# 133548  131632   291.75     32  POJMI4.asc  unknown  7570648  658.5    495
# 133549  131632   291.75     32  POJMI4.asc  unknown  7570650  659.1  497.6
# 133550  131632   291.75     32  POJMI4.asc  unknown  7570652  659.9  500.1
# 133551  131632   291.75     32  POJMI4.asc  unknown  7570654  660.5  502.4
# 133552  131632   291.75     32  POJMI4.asc  unknown  7570656  661.2  504.4
# 133553  131632   291.75     32  POJMI4.asc  unknown  7570658  661.9  506.1
# 133554  131632   291.75     32  POJMI4.asc  unknown  7570660  662.6  507.5
# 133555  131632   291.75     32  POJMI4.asc  unknown  7570662  663.5  508.4
#
#         pupsize  timing   ...   one dot1 dot2 dot3 trialfalse  NOCLICK  \
# 0         710.0       1   ...     1    .    .    .     trial2  NOCLICK
# 1         710.0       3   ...     1    .    .    .     trial2  NOCLICK
# 2         710.0       5   ...     1    .    .    .     trial2  NOCLICK
# 3         710.0       7   ...     1    .    .    .     trial2  NOCLICK
# 4         710.0       9   ...     1    .    .    .     trial2  NOCLICK
# 5         710.0      11   ...     1    .    .    .     trial2  NOCLICK
# 6         710.0      13   ...     1    .    .    .     trial2  NOCLICK
# 7         709.0      15   ...     1    .    .    .     trial2  NOCLICK
# 8         709.0      17   ...     1    .    .    .     trial2  NOCLICK
# 9         709.0      19   ...     1    .    .    .     trial2  NOCLICK
# 10        709.0      21   ...     1    .    .    .     trial2  NOCLICK
# 11        710.0      23   ...     1    .    .    .     trial2  NOCLICK
# 12        710.0      25   ...     1    .    .    .     trial2  NOCLICK
# 13        710.0      27   ...     1    .    .    .     trial2  NOCLICK
# 14        711.0      29   ...     1    .    .    .     trial2  NOCLICK
# 15        711.0      31   ...     1    .    .    .     trial2  NOCLICK
# 16        711.0      33   ...     1    .    .    .     trial2  NOCLICK
# 17        711.0      35   ...     1    .    .    .     trial2  NOCLICK
# 18        711.0      37   ...     1    .    .    .     trial2  NOCLICK
# 19        711.0      39   ...     1    .    .    .     trial2  NOCLICK
# 20        711.0      41   ...     1    .    .    .     trial2  NOCLICK
# 21        711.0      43   ...     1    .    .    .     trial2  NOCLICK
# 22        711.0      45   ...     1    .    .    .     trial2  NOCLICK
# 23        711.0      47   ...     1    .    .    .     trial2  NOCLICK
# 24        711.0      49   ...     1    .    .    .     trial2  NOCLICK
# 25        710.0      51   ...     1    .    .    .     trial2  NOCLICK
# 26        710.0      53   ...     1    .    .    .     trial2  NOCLICK
# 27        710.0      55   ...     1    .    .    .     trial2  NOCLICK
# 28        710.0      57   ...     1    .    .    .     trial2  NOCLICK
# 29        710.0      59   ...     1    .    .    .     trial2  NOCLICK
# ...         ...     ...   ...    ..  ...  ...  ...        ...      ...
# 133526    294.0    8288   ...     1    .    .    .    trial31  NOCLICK
# 133527    294.0    8290   ...     1    .    .    .    trial31  NOCLICK
# 133528    294.0    8292   ...     1    .    .    .    trial31  NOCLICK
# 133529    295.0    8294   ...     1    .    .    .    trial31  NOCLICK
# 133530    295.0    8296   ...     1    .    .    .    trial31  NOCLICK
# 133531    295.0    8298   ...     1    .    .    .    trial31  NOCLICK
# 133532    295.0    8300   ...     1    .    .    .    trial31  NOCLICK
# 133533    295.0    8302   ...     1    .    .    .    trial31  NOCLICK
# 133534    295.0    8304   ...     1    .    .    .    trial31  NOCLICK
# 133535    295.0    8306   ...     1    .    .    .    trial31  NOCLICK
# 133536    295.0    8308   ...     1    .    .    .    trial31  NOCLICK
# 133537    295.0    8310   ...     1    .    .    .    trial31  NOCLICK
# 133538    295.0    8312   ...     1    .    .    .    trial31  NOCLICK
# 133539    295.0    8314   ...     1    .    .    .    trial31  NOCLICK
# 133540    295.0    8316   ...     1    .    .    .    trial31  NOCLICK
# 133541    295.0    8318   ...     1    .    .    .    trial31  NOCLICK
# 133542    295.0    8320   ...     1    .    .    .    trial31  NOCLICK
# 133543    295.0    8322   ...     1    .    .    .    trial31  NOCLICK
# 133544    295.0    8324   ...     1    .    .    .    trial31  NOCLICK
# 133545    295.0    8326   ...     1    .    .    .    trial31  NOCLICK
# 133546    296.0    8328   ...     1    .    .    .    trial31  NOCLICK
# 133547    296.0    8330   ...     1    .    .    .    trial31  NOCLICK
# 133548    296.0    8332   ...     1    .    .    .    trial31  NOCLICK
# 133549    297.0    8334   ...     1    .    .    .    trial31  NOCLICK
# 133550    298.0    8336   ...     1    .    .    .    trial31  NOCLICK
# 133551    298.0    8338   ...     1    .    .    .    trial31  NOCLICK
# 133552    299.0    8340   ...     1    .    .    .    trial31  NOCLICK
# 133553    299.0    8342   ...     1    .    .    .    trial31  NOCLICK
# 133554    299.0    8344   ...     1    .    .    .    trial31  NOCLICK
# 133555    299.0    8346   ...     1    .    .    .    trial31  NOCLICK
#
#         noclick newtiming interp_pupsize  bvaled
# 0       noclick         2          710.0  184.00
# 1       noclick         4          710.0  184.00
# 2       noclick         6          710.0  184.00
# 3       noclick         8          710.0  184.00
# 4       noclick        10          710.0  184.00
# 5       noclick        12          710.0  184.00
# 6       noclick        14          710.0  184.00
# 7       noclick        16          709.0  183.00
# 8       noclick        18          709.0  183.00
# 9       noclick        20          709.0  183.00
# 10      noclick        22          709.0  183.00
# 11      noclick        24          710.0  184.00
# 12      noclick        26          710.0  184.00
# 13      noclick        28          710.0  184.00
# 14      noclick        30          711.0  185.00
# 15      noclick        32          711.0  185.00
# 16      noclick        34          711.0  185.00
# 17      noclick        36          711.0  185.00
# 18      noclick        38          711.0  185.00
# 19      noclick        40          711.0  185.00
# 20      noclick        42          711.0  185.00
# 21      noclick        44          711.0  185.00
# 22      noclick        46          711.0  185.00
# 23      noclick        48          711.0  185.00
# 24      noclick        50          711.0  185.00
# 25      noclick        52          710.0  184.00
# 26      noclick        54          710.0  184.00
# 27      noclick        56          710.0  184.00
# 28      noclick        58          710.0  184.00
# 29      noclick        60          710.0  184.00
# ...         ...       ...            ...     ...
# 133526  noclick      8288          294.0    2.25
# 133527  noclick      8290          294.0    2.25
# 133528  noclick      8292          294.0    2.25
# 133529  noclick      8294          295.0    3.25
# 133530  noclick      8296          295.0    3.25
# 133531  noclick      8298          295.0    3.25
# 133532  noclick      8300          295.0    3.25
# 133533  noclick      8302          295.0    3.25
# 133534  noclick      8304          295.0    3.25
# 133535  noclick      8306          295.0    3.25
# 133536  noclick      8308          295.0    3.25
# 133537  noclick      8310          295.0    3.25
# 133538  noclick      8312          295.0    3.25
# 133539  noclick      8314          295.0    3.25
# 133540  noclick      8316          295.0    3.25
# 133541  noclick      8318          295.0    3.25
# 133542  noclick      8320          295.0    3.25
# 133543  noclick      8322          295.0    3.25
# 133544  noclick      8324          295.0    3.25
# 133545  noclick      8326          295.0    3.25
# 133546  noclick      8328          296.0    4.25
# 133547  noclick      8330          296.0    4.25
# 133548  noclick      8332          296.0    4.25
# 133549  noclick      8334          297.0    5.25
# 133550  noclick      8336          298.0    6.25
# 133551  noclick      8338          298.0    6.25
# 133552  noclick      8340          299.0    7.25
# 133553  noclick      8342          299.0    7.25
# 133554  noclick      8344          299.0    7.25
# 133555  noclick      8346          299.0    7.25
#
# [133556 rows x 25 columns]

# %%
# #ideally you would up load a csv that is a list of your csv names and then make that equal to ex_csv_loop
# #so it would look like
# #data_loop = list
# data_loop = '../data/'
# ex_csv_loop=
# ex_csv_loop=["POJIL1.csv", "POJJN4.csv", "POJMI4.csv"]
# for i in range(len(ex_csv_loop))
#     data_loop = ex_csv_loop[i]

# %%
###### DO ALL OF THE ABOVE FOR EACH SUBJECT INDIVIDUALLY. ONCE EACH SUBJECTS TIMING INFORMATION HAS BEEN CHANGED
# TO EVENS, THE PUPILSIZE HAS BEEN INTERPOLATED, AND WE HAVE THE VALUES MINUS THE BASELINE,.... 
# THEN WE CAN CONCATENATE/ADD/MERGE (WHATEVER THE COMMAND IS) ALL OF THE SUBJECTS DATA FILES TO DO "GROUPBY" AND PLOT.

# %%
#make a new directory and save result to a csv with i value name

# %%
by_row_index = result.groupby(['condition','newtiming'])

# %%
by_row_index.head()

# %%
by_row_index = result.groupby(['condition','newtiming'])
df_means = by_row_index.mean()
df_means

# %%
fig, ax = plt.subplots(figsize=(10,10))
result.groupby(['newtiming', 'condition']).mean()['bvaled'].unstack().plot(ax = ax)

# %%
data.groupby(['date','type']).count()['amount'].unstack().plot(ax=ax)

# %%
result.newtiming[result.newtiming==4500] #indexing pandas df to find where this is true
len(result.newtiming[result.newtiming==4500])#double checks that there are 32 instances
baseline_nt=result.newtiming[result.newtiming==4500].index.tolist()#makes a list of the indicies in result df that are 4500
baseline_nt

result['bvalue'] = []

# %%
#moved this cell up bc need to interpolate before doing the baseline subtraction

interp_pupsize= result.pupsize.interpolate()#(method='spline', order=2) #figuring out how we want to interp
plt.plot(interp_pupsize)
len(interp_pupsize)

# %%
forbaseline.merge(result, on = 'trial', how = 'right')

# %%
result.bvalue[2] = 3

# %%
result.head()

# %%
baseline_pupsize=[]
for i in baseline_nt:
    baseline_pupsize.append(result_1.interp_pupsize[i])#this works when we use result not result_1 
    #need to figure out whats going on after interpolation. I think when we interpolate it may over write the nans
    #so we do not need to make a new column of interp and append it to result. 
    
    
#next after this ^^ works take each value and subtract it from each corresponding trial group 
    #skeleton
    baseline_complete = []
    if trial i = baseline_pupsize.index[i]:#trying to match index with trial, will need to figure out the whole python 0 thing
        basline_complete.append(result.pupsize[i]-baseline_pupsize[i])

# %%
result.newtiming[result.newtiming==4500]

# %%
now need to find the pupil size at each index once for each trial number 
need to subtract the pupil size at the 4500 timepoint @trial one for all trial ones

# %%
result.plot(x='newtiming', y='pupsize', label='trial')

# %%
result_1 = pd.concat([result, interp_pupsize], axis=1)

#result_1 = result.rename(columns = {0:'interp'})

# %%
result_1.plot(x='newtiming', y='pupsize', label='trial')

# %%
result_1.head(450)

# %%
#trying to compare graphs with Reinas 
#will need to baseline this and look at pupsize change 
axes = plt.gca()

axes.set_xlim([0,8500])
axes.set_ylim(new_timing)
axes.plot(interp_pupsize)

# %%
#to get an idea of how many positions we changed to NaNs and are interpolating
len(result.pupsize[result.pupsize.isnull()])

# %%
interp_pupsize[131635:131732]

# %%
#try to see looping everything how long it works with first interp method

# try using numpy.where for new method

#something that we can just see where the NaNs or 0's so that we dont have to loop through specific section of the code
#aka it gets everything in one run for the new method

# %%
trials column 
in each trial timing goes 0 8000

each trial there are 32 per sub 

find the pupsize at time point 4500 ms

then make new column pupsize - pupsize @ time point 4500

new

# %%
Next step: Find the baseline value for each trial. To do this we need a vector of the pupil size at 
    timepoint 4500 for each trial as described above. 
    
    
if statement finding only 4500ms in the newtiming column

# %%
result.newtiming[2]

# %%
baseline_vs=[4500]
ix = np.isin(result.newtiming,basline_vs)
np.where(ix)

# %%
goodvalues = [3, 4, 7]
ix = np.isin(x, goodvalues)
ix
array([[False, False, False],
       [ True,  True, False],
       [False,  True, False]])
np.where(ix)
(array([1, 1, 2]), array([0, 1, 1]))

# %%
np.__version__

# %%
range(len(result.trial.unique()))
