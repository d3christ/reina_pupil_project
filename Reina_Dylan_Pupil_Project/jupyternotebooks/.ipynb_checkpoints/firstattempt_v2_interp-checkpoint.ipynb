# %% [markdown]
# Loading in Pupil Data

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data_file = '../data/POJMI4.csv'
colnames =["subject","unknown", "nums", "xcoor", "ycoor", "pupsize", "timing", "trial","experiment", "tone1", "tone2", "condition", "image", "one", "dot1", "dot2", "dot3", "trialfalse", "NOCLICK", "noclick"]
df_podcdat = pd.read_csv(data_file, names=colnames)

# %%
#make a temp list of file names, then have a loop through this list to then upload into this scrip
#should look like
#df_podcdat = pd.read_csv('temp[i]', names=colnames)

# %%
# #ideally you would up load a csv that is a list of your csv names and then make that equal to ex_csv_loop
# #so it would look like
# #data_loop = list
# data_loop = '../data/'
# ex_csv_loop=
# ex_csv_loop=["POJIL1.csv", "POJJN4.csv", "POJMI4.csv"]
# for i in range(len(ex_csv_loop))
#     data_loop = ex_csv_loop[i]

# %% [markdown]
# Making new timing column of even numbers

# %%
#put timing column into list to make easier to work with pandas
timing = df_podcdat.timing.tolist()
pupsize = df_podcdat.pupsize.tolist()

# %%
new_timing=[]
for i in range(len(timing)):#Start from begining to end of timing list
    num = timing[i]#set num = to timing at specific location in list
    if num%2 !=0:# if number divided by 2 has a remainder that is not 0
        num = num + 1 # take that number with the nonzero remainder and add one to it
        new_timing.append(num)# take the new number and append it to the new_timing list
    else:# if the number is even
        new_timing.append(num)# take the even number and append it to the new_timing list
(len(timing),len(new_timing)) # show me the length of the old timing list with the new timing list to double check we
# have the same number of values

new_timing = pd.DataFrame(new_timing)

# %%
result = pd.concat([df_podcdat, new_timing], axis=1)
result = result.rename(columns = {0:'newtiming'})

# %% [markdown]
# Indexing a list of pupil sizes where the values in the data are zero

# %%
pup_zeros=[]
for i in range(len(pupsize)):#Start from begining to end of pupsize list
    num = pupsize[i]#set num = to pupsize at specific location in list, index?
    if num == 0:# if number is 0
        pup_zeros.append(i)# take the index location and append it to the pup_zeros list
(len(pupsize),len(pup_zeros)) # show me the length of the pupsize list with the pup_zeros list to check it looks right
# Out:
# (133556, 3623)

# %%
pup_array=np.asarray(pupsize)
np.where(pup_array==0)
# Out:
# (array([   450,    451,    452, ..., 131732, 131733, 131734]),)

# %%
pz = pd.DataFrame(pup_zeros)
pup_all = pd.DataFrame().reindex_like(pz)
before = pd.DataFrame().reindex_like(pz)
after = pd.DataFrame().reindex_like(pz)

# %%
pup_all = pup_all.rename(columns = {0:'original'})
before = before.rename(columns = {0:'before'})
after = after.rename(columns = {0:'after'})
pup_all = pd.concat([pup_all, before, after],axis=1)

# %%
for i in range(len(pup_zeros)):
    pup_all.original[i] = pup_zeros[i]
    pup_all.before[i] = pup_zeros[i] - 75
    pup_all.after[i] = pup_zeros[i] + 75
    

#group by sequence
#take list value by value find one not a number in sequence pull and store index of 150 samples before vlaue 
#then if next not is only one greater then last one if it is greater make that a new one

# %% [markdown]
# New Method of interpolation. W.I.P.

# %%
#interp 1.2
#works!!!! but now lets see if it is actually doing what i think it is doing 
for i in range(len(result)):
    if result.pupsize[i]==0:
        before=i-75
        after=i+75
        result.pupsize.ix[before:after] = np.nan
        
print("done")
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# done

# %%
result.newtiming[result.newtiming==4500] #indexing pandas df to find where this is true

# %%
len(result.newtiming[result.newtiming==4500])#double checks that there are 32 instances
# Out:
# 32

# %%
baseline_nt=result.newtiming[result.newtiming==4500].index.tolist()#makes a list of the indicies in result df that are 4500

baseline_nt
# Out:
# [2249,
#  6424,
#  10599,
#  14774,
#  18949,
#  23123,
#  27297,
#  31472,
#  35645,
#  39820,
#  43985,
#  48160,
#  52334,
#  56508,
#  60682,
#  64855,
#  69030,
#  73203,
#  77378,
#  81551,
#  85726,
#  89900,
#  94074,
#  98248,
#  102422,
#  106596,
#  110770,
#  114944,
#  119110,
#  123284,
#  127458,
#  131632]

# %%
#moved this cell up bc need to interpolate before doing the baseline subtraction

interp_pupsize= result.pupsize.interpolate()#(method='spline', order=2) #figuring out how we want to interp
plt.plot(interp_pupsize)
len(interp_pupsize)
# Out:
# 133556

# %%
baseline_pupsize=[]
for i in baseline_nt:
    baseline_pupsize.append(result_1.interp_pupsize[i])#this works when we use result not result_1 
    #need to figure out whats going on after interpolation. I think when we interpolate it may over write the nans
    #so we do not need to make a new column of interp and append it to result. 
    
    
#next after this ^^ works take each value and subtract it from each corresponding trial group 
    #skeleton
    baseline_complete = []
    if trial i = baseline_pupsize.index[i]:#trying to match index with trial, will need to figure out the whole python 0 thing
        basline_complete.append(result.pupsize[i]-baseline_pupsize[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-90c0843659eb> in <module>()
#       1 baseline_pupsize=[]
#       2 for i in baseline_nt:
# ----> 3     baseline_pupsize.append(result_1.interp_pupsize[i])
#       4
#       5
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'interp_pupsize'

# %%
result.newtiming[result.newtiming==4500]
# Out:
# 2249      4500
# 6424      4500
# 10599     4500
# 14774     4500
# 18949     4500
# 23123     4500
# 27297     4500
# 31472     4500
# 35645     4500
# 39820     4500
# 43985     4500
# 48160     4500
# 52334     4500
# 56508     4500
# 60682     4500
# 64855     4500
# 69030     4500
# 73203     4500
# 77378     4500
# 81551     4500
# 85726     4500
# 89900     4500
# 94074     4500
# 98248     4500
# 102422    4500
# 106596    4500
# 110770    4500
# 114944    4500
# 119110    4500
# 123284    4500
# 127458    4500
# 131632    4500
# Name: newtiming, dtype: int64

# %%
now need to find the pupil size at each index once for each trial number 
need to subtract the pupil size at the 4500 timepoint @trial one for all trial ones

# %%
result.plot(x='newtiming', y='pupsize', label='trial')

# %%
result_1 = pd.concat([result, interp_pupsize], axis=1)

#result_1 = result.rename(columns = {0:'interp'})

# %%
result_1.plot(x='newtiming', y='pupsize', label='trial')

# %%
result_1.head(450)
# Out:
#         subject  unknown     nums   xcoor  ycoor pupsize  timing  trial  \
# 0    POJMI4.asc  unknown  7232610   619.2  535.2   710.0       1      1
# 1    POJMI4.asc  unknown  7232612   619.2    535   710.0       3      1
# 2    POJMI4.asc  unknown  7232614   619.2  534.8   710.0       5      1
# 3    POJMI4.asc  unknown  7232616   619.2  534.8   710.0       7      1
# 4    POJMI4.asc  unknown  7232618   619.2  535.1   710.0       9      1
# 5    POJMI4.asc  unknown  7232620   619.1  535.5   710.0      11      1
# 437  POJMI4.asc  unknown  7233484   571.7    504     NaN     875      1
# 438  POJMI4.asc  unknown  7233486   571.7  503.8     NaN     877      1
# 439  POJMI4.asc  unknown  7233488   571.9  504.8     NaN     879      1
# 440  POJMI4.asc  unknown  7233490   572.6  505.8     NaN     881      1
# 441  POJMI4.asc  unknown  7233492   573.5    507     NaN     883      1
# 442  POJMI4.asc  unknown  7233494   574.5  508.2     NaN     885      1
# 443  POJMI4.asc  unknown  7233496   575.3  505.4     NaN     887      1
# 444  POJMI4.asc  unknown  7233498     576  498.6     NaN     889      1
# 445  POJMI4.asc  unknown  7233500   575.4  475.8     NaN     891      1
# 446  POJMI4.asc  unknown  7233502   572.2  452.3     NaN     893      1
# 447  POJMI4.asc  unknown  7233504     569  428.6     NaN     895      1
# 448  POJMI4.asc  unknown  7233506   565.6  404.8     NaN     897      1
# 449  POJMI4.asc  unknown  7233508  -584.9  435.8     NaN     899      1
#
#     experiment tone1     ...           image one dot1  dot2 dot3 trialfalse  \
# 0           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 1           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 2           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 3           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 4           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 5           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 6           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 7           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 8           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 9           PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 10          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 11          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 12          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 13          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 14          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 15          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 16          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 17          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 18          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 19          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 20          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 21          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 22          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 23          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 24          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 25          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 26          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 27          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 28          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 29          PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# ..         ...   ...     ...             ...  ..  ...   ...  ...        ...
# 420         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 421         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 422         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 423         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 424         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 425         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 426         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 427         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 428         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 429         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 430         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 431         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 432         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 433         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 434         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 435         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 436         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 437         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 438         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 439         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 440         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 441         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 442         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 443         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 444         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 445         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 446         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 447         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 448         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
# 449         PO  CGVV     ...      new31.jpeg   1    .     .    .     trial2
#
#      NOCLICK  noclick newtiming     pupsize
# 0    NOCLICK  noclick         2  710.000000
# 1    NOCLICK  noclick         4  710.000000
# 2    NOCLICK  noclick         6  710.000000
# 3    NOCLICK  noclick         8  710.000000
# 4    NOCLICK  noclick        10  710.000000
# 5    NOCLICK  noclick        12  710.000000
# 6    NOCLICK  noclick        14  710.000000
# 7    NOCLICK  noclick        16  709.000000
# 8    NOCLICK  noclick        18  709.000000
# 9    NOCLICK  noclick        20  709.000000
# 10   NOCLICK  noclick        22  709.000000
# 11   NOCLICK  noclick        24  710.000000
# 12   NOCLICK  noclick        26  710.000000
# 13   NOCLICK  noclick        28  710.000000
# 14   NOCLICK  noclick        30  711.000000
# 15   NOCLICK  noclick        32  711.000000
# 16   NOCLICK  noclick        34  711.000000
# 17   NOCLICK  noclick        36  711.000000
# 18   NOCLICK  noclick        38  711.000000
# 19   NOCLICK  noclick        40  711.000000
# 20   NOCLICK  noclick        42  711.000000
# 21   NOCLICK  noclick        44  711.000000
# 22   NOCLICK  noclick        46  711.000000
# 23   NOCLICK  noclick        48  711.000000
# 24   NOCLICK  noclick        50  711.000000
# 25   NOCLICK  noclick        52  710.000000
# 26   NOCLICK  noclick        54  710.000000
# 27   NOCLICK  noclick        56  710.000000
# 28   NOCLICK  noclick        58  710.000000
# 29   NOCLICK  noclick        60  710.000000
# ..       ...      ...       ...         ...
# 420  NOCLICK  noclick       842  665.566890
# 421  NOCLICK  noclick       844  665.399470
# 422  NOCLICK  noclick       846  665.234422
# 423  NOCLICK  noclick       848  665.071746
# 424  NOCLICK  noclick       850  664.911443
# 425  NOCLICK  noclick       852  664.753511
# 426  NOCLICK  noclick       854  664.597952
# 427  NOCLICK  noclick       856  664.444764
# 428  NOCLICK  noclick       858  664.293949
# 429  NOCLICK  noclick       860  664.145506
# 430  NOCLICK  noclick       862  663.999435
# 431  NOCLICK  noclick       864  663.855736
# 432  NOCLICK  noclick       866  663.714409
# 433  NOCLICK  noclick       868  663.575454
# 434  NOCLICK  noclick       870  663.438871
# 435  NOCLICK  noclick       872  663.304660
# 436  NOCLICK  noclick       874  663.172822
# 437  NOCLICK  noclick       876  663.043355
# 438  NOCLICK  noclick       878  662.916261
# 439  NOCLICK  noclick       880  662.791538
# 440  NOCLICK  noclick       882  662.669188
# 441  NOCLICK  noclick       884  662.549210
# 442  NOCLICK  noclick       886  662.431604
# 443  NOCLICK  noclick       888  662.316370
# 444  NOCLICK  noclick       890  662.203508
# 445  NOCLICK  noclick       892  662.093018
# 446  NOCLICK  noclick       894  661.984900
# 447  NOCLICK  noclick       896  661.879155
# 448  NOCLICK  noclick       898  661.775781
# 449  NOCLICK  noclick       900  661.674780
#
# [450 rows x 22 columns]

# %%
#trying to compare graphs with Reinas 
#will need to baseline this and look at pupsize change 
axes = plt.gca()

axes.set_xlim([0,8500])
axes.set_ylim(new_timing)
axes.plot(interp_pupsize)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-abee8426b47d> in <module>()
#       4
#       5 axes.set_xlim([0,8500])
# ----> 6 axes.set_ylim(new_timing)
#       7 axes.plot(interp_pupsize)
#
# /Applications/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, **kw)
#    3159
#    3160         if top is None and iterable(bottom):
# -> 3161             bottom, top = bottom
#    3162
#    3163         if bottom is not None:
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
#to get an idea of how many positions we changed to NaNs and are interpolating
len(result.pupsize[result.pupsize.isnull()])

# %%
interp_pupsize[131635:131732]

# %%
#try to see looping everything how long it works with first interp method

# try using numpy.where for new method

#something that we can just see where the NaNs or 0's so that we dont have to loop through specific section of the code
#aka it gets everything in one run for the new method

# %%
trials column 
in each trial timing goes 0 8000

each trial there are 32 per sub 

find the pupsize at time point 4500 ms

then make new column pupsize - pupsize @ time point 4500

new

# %%
Next step: Find the baseline value for each trial. To do this we need a vector of the pupil size at 
    timepoint 4500 for each trial as described above. 
    
    
if statement finding only 4500ms in the newtiming column

# %%
result.newtiming[2]
# Out:
# 6

# %%
baseline_vs=[4500]
ix = np.isin(result.newtiming,basline_vs)
np.where(ix)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-e4fd8cde771b> in <module>()
#       1 baseline_vs=[4500]
# ----> 2 ix = np.isin(result.newtiming,basline_vs)
#       3 np.where(ix)
#
# AttributeError: module 'numpy' has no attribute 'isin'

# %%
goodvalues = [3, 4, 7]
ix = np.isin(x, goodvalues)
ix
array([[False, False, False],
       [ True,  True, False],
       [False,  True, False]])
np.where(ix)
(array([1, 1, 2]), array([0, 1, 1]))

# %%
np.__version__
# Out:
# '1.11.1'

# %%
range(len(result.trial.unique()))
# Out:
# range(0, 32)
