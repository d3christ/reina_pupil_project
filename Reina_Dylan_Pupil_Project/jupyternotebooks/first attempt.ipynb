# %%
import numpy as np
import pandas as pd
colnames=['subject','unknown','nums','xcoor','ycoor','pupsize','timing','trial','experiment','tone1','tone2','condition','image']
df_podcdat = pd.read_csv('podcdat.csv', names=colnames)
#put timing column into list to make easier to work with pandas
timing = df_podcdat.timing.tolist()
pupsize = df_podcdat.pupsize.tolist()

# %%
new_timing=[]
for i in range(len(timing)):#Start from begining to end of timing list
    num = timing[i]#set num = to timing at specific location in list
    if num%2 !=0:# if number divided by 2 has a remainder that is not 0
        num = num + 1 # take that number with the nonzero remainder and add one to it
        new_timing.append(num)# take the new number and append it to the new_timing list
    else:# if the number is even
        new_timing.append(num)# take the even number and append it to the new_timing list
(len(timing),len(new_timing)) # show me the length of the old timing list with the new timing list to double check we
# have the same number of values
# Out:
# (133522, 133522)

# %%
colnames_2=['new_timing']
df_new_timing = pd.read_csv('out.csv', names=colnames_2)
#combining two data sets df_podcdat with new_timing
result = pd.concat([df_podcdat, df_new_timing], axis=1)
#reordering the combined data sets so that the new timing and old timing are next to each other
result = result[['subject','unknown','nums','xcoor','ycoor','pupsize','timing','new_timing','trial','experiment','tone1','tone2','condition','image']]

# %%
pup_zeros=[]
for i in range(len(pupsize)):#Start from begining to end of pupsize list
    num = pupsize[i]#set num = to pupsize at specific location in list, index?
    if num == 0:# if number is 0
        pup_zeros.append(i)# take the index location and append it to the pup_zeros list
(len(pupsize),len(pup_zeros)) # show me the length of the pupsize list with the pup_zeros list to check it looks right
# Out:
# (133522, 3967)

# %%
pup_array=np.asarray(pupsize)
np.where(pup_array==0)
#hi=np.where(pup_array==0)
#hi
#hey=(pup_array==0).sum()
#hey

# %%
pz = pd.DataFrame(pup_zeros)
pup_all = pd.DataFrame().reindex_like(pz)
before = pd.DataFrame().reindex_like(pz)
after = pd.DataFrame().reindex_like(pz)

# %%
pup_all = pup_all.rename(columns = {0:'original'})
pup_all.head()
# Out:
#    original
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
before = before.rename(columns = {0:'before'})
before.head()
# Out:
#    before
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
after = after.rename(columns = {0:'after'})
after.head()
# Out:
#    after
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
pup_all = pd.concat([pup_all, before, after],axis=1)
pup_all.head()
# Out:
#    original  before  after
# 0       NaN     NaN    NaN
# 1       NaN     NaN    NaN
# 2       NaN     NaN    NaN
# 3       NaN     NaN    NaN
# 4       NaN     NaN    NaN

# %%
for i in range(len(pup_zeros)):
    pup_all.original[i] = pup_zeros[i]
    pup_all.before[i] = pup_zeros[i] - 75
    pup_all.after[i] = pup_zeros[i] + 75

# %%
pup_all.head()
# Out:
#    original  before  after
# 0     350.0   275.0  425.0
# 1     351.0   276.0  426.0
# 2     352.0   277.0  427.0
# 3     353.0   278.0  428.0
# 4     354.0   279.0  429.0

# %%
pup_all.before[0]
# Out:
# 275.0

# %%
pup_all.before.set_value

# %%
#result.pupsize[(result.pupsize[275,425])]=np.nan

# %%
for i in range(len(pup_all)):
    #result.set_value(#beforetime:#after number,@column pupsize, None)
    #result.set_value((pup_all.before[i]:pup_all.after[i]),result.pupsize,None)
    result.set_value((pup_all.before[i]),result.pupsize,None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in set_value(self, index, col, value, takeable)
#    1923
# -> 1924             series = self._get_item_cache(col)
#    1925             engine = self.index._engine
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1383         cache = self._item_cache
# -> 1384         res = cache.get(item)
#    1385         if res is None:
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __hash__(self)
#     830         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 831                         ' hashed'.format(self.__class__.__name__))
#     832
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-6c7461589e31> in <module>()
#       2     #result.set_value(#beforetime:#after number,@column pupsize, None)
#       3     #result.set_value((pup_all.before[i]:pup_all.after[i]),result.pupsize,None)
# ----> 4     result.set_value((pup_all.before[i]),result.pupsize,None)
#       5
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in set_value(self, index, col, value, takeable)
#    1929
#    1930             # set using a non-recursive method & reset the cache
# -> 1931             self.loc[index, col] = value
#    1932             self._item_cache.pop(col, None)
#    1933
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     138         else:
#     139             key = com._apply_if_callable(key, self.obj)
# --> 140         indexer = self._get_setitem_indexer(key)
#     141         self._setitem_with_indexer(indexer, value)
#     142
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     120
#     121         if isinstance(key, tuple) and not self.ndim < len(key):
# --> 122             return self._convert_tuple(key, is_setter=True)
#     123         if isinstance(key, range):
#     124             return self._convert_range(key, is_setter=True)
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_tuple(self, key, is_setter)
#     182         else:
#     183             for i, k in enumerate(key):
# --> 184                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     185                 keyidx.append(idx)
#     186         return tuple(keyidx)
#
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1228                 mask = check == -1
#    1229                 if mask.any():
# -> 1230                     raise KeyError('%s not in index' % objarr[mask])
#    1231
#    1232                 return _values_from_object(indexer)
#
# KeyError: '[714 714 713 ..., 252 252 252] not in index'

# %%
result.pupsize = result.pupsize.replace(range(275,425), None)

# %%
whos
# Out:
# Variable          Type         Data/Info
# ----------------------------------------
# after             DataFrame          after\n0       NaN\<...>\n[3967 rows x 1 columns]
# before            DataFrame          before\n0        Na<...>\n[3967 rows x 1 columns]
# colnames          list         n=13
# colnames_2        list         n=1
# df_new_timing     DataFrame            new_timing\n0    <...>[133522 rows x 1 columns]
# df_podcdat        DataFrame              subject  unknow<...>133522 rows x 13 columns]
# i                 int          3966
# new_timing        list         n=133522
# np                module       <module 'numpy' from '/Ap<...>kages/numpy/__init__.py'>
# num               int          411
# pd                module       <module 'pandas' from '/A<...>ages/pandas/__init__.py'>
# pup_above_below   range        range(133323, 133473)
# pup_all           DataFrame          original    before <...>\n[3967 rows x 3 columns]
# pup_zeros         list         n=3967
# pupsize           list         n=133522
# pz                DataFrame               0\n0        35<...>\n[3967 rows x 1 columns]
# result            DataFrame              subject  unknow<...>133522 rows x 14 columns]
# start             int          133323
# stop              int          133473
# timing            list         n=133522

# %%
for i in range(len(pupsize)):
result.pupsize[(result.pupsize=pup_all.before.
df[(df>=-200) & (df<=-100)] = np.nan

# %%
pup_all=[]
for i in range(len(pupsize)):#Start from begining to end of pupsize list
    num = pupsize[i]#set num = to pupsize at specific location in list, index?
    if num == 0:# if number is 0
        start = i - 75
        stop = i + 75
        pup_above_below=range(start,stop)
        pup_all.append(list(pup_above_below))

# %%
# Out:
# Variable          Type         Data/Info
# ----------------------------------------
# after             DataFrame          after\n0       NaN\<...>\n[3967 rows x 1 columns]
# before            DataFrame          before\n0        Na<...>\n[3967 rows x 1 columns]
# colnames          list         n=13
# colnames_2        list         n=1
# df_new_timing     DataFrame            new_timing\n0    <...>[133522 rows x 1 columns]
# df_podcdat        DataFrame              subject  unknow<...>133522 rows x 13 columns]
# i                 int          3966
# new_timing        list         n=133522
# np                module       <module 'numpy' from '/Ap<...>kages/numpy/__init__.py'>
# num               int          411
# pd                module       <module 'pandas' from '/A<...>ages/pandas/__init__.py'>
# pup_above_below   range        range(133323, 133473)
# pup_all           DataFrame          original    before <...>\n[3967 rows x 3 columns]
# pup_zeros         list         n=3967
# pupsize           list         n=133522
# pz                DataFrame               0\n0        35<...>\n[3967 rows x 1 columns]
# result            DataFrame              subject  unknow<...>133522 rows x 14 columns]
# start             int          133323
# stop              int          133473
# timing            list         n=133522

# %%
#np.where(i>(i-150))
