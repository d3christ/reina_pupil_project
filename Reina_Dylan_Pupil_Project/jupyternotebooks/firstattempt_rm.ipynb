# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
colnames=['subject','unknown','nums','xcoor','ycoor','pupsize','timing','trial','experiment','tone1','tone2','condition','image']
df_podcdat = pd.read_csv('podcdat.csv', names=colnames)
#put timing column into list to make easier to work with pandas
timing = df_podcdat.timing.tolist()
pupsize = df_podcdat.pupsize.tolist()

# %%
new_timing=[]
for i in range(len(timing)):#Start from begining to end of timing list
    num = timing[i]#set num = to timing at specific location in list
    if num%2 !=0:# if number divided by 2 has a remainder that is not 0
        num = num + 1 # take that number with the nonzero remainder and add one to it
        new_timing.append(num)# take the new number and append it to the new_timing list
    else:# if the number is even
        new_timing.append(num)# take the even number and append it to the new_timing list
(len(timing),len(new_timing)) # show me the length of the old timing list with the new timing list to double check we
# have the same number of values

new_timing = pd.DataFrame(new_timing)

# %%
new_timing.head()
# Out:
#       0
# 0   2.0
# 1   4.0
# 2   6.0
# 3   8.0
# 4  10.0

# %%
result = pd.concat([df_podcdat, new_timing], axis=1)
result = result.rename(columns = {0:'newtiming'})
result.head()
# Out:
#      subject  unknown    nums  xcoor  ycoor  pupsize  timing  trial  \
# 0  PODC1.asc  unknown  583211  658.7    534      714     1.0      1
# 1  PODC1.asc  unknown  583213  659.8  534.1      714     3.0      1
# 2  PODC1.asc  unknown  583215  660.8  534.2      713     5.0      1
# 3  PODC1.asc  unknown  583217  661.6  534.4      713     7.0      1
# 4  PODC1.asc  unknown  583219  661.6  534.6      712     9.0      1
#
#   experiment tone1 tone2 condition       image  newtiming
# 0         PO  CGTT     F    dv.wav  new32.jpeg        2.0
# 1         PO  CGTT     F    dv.wav  new32.jpeg        4.0
# 2         PO  CGTT     F    dv.wav  new32.jpeg        6.0
# 3         PO  CGTT     F    dv.wav  new32.jpeg        8.0
# 4         PO  CGTT     F    dv.wav  new32.jpeg       10.0

# %%
pup_zeros=[]
for i in range(len(pupsize)):#Start from begining to end of pupsize list
    num = pupsize[i]#set num = to pupsize at specific location in list, index?
    if num == 0:# if number is 0
        pup_zeros.append(i)# take the index location and append it to the pup_zeros list
(len(pupsize),len(pup_zeros)) # show me the length of the pupsize list with the pup_zeros list to check it looks right
# Out:
# (133522, 3967)

# %%
pup_array=np.asarray(pupsize)
np.where(pup_array==0)
#hi=np.where(pup_array==0)
#hi
#hey=(pup_array==0).sum()
#hey
# Out:
# (array([   350,    351,    352, ..., 133396, 133397, 133398]),)

# %%
pz = pd.DataFrame(pup_zeros)
pup_all = pd.DataFrame().reindex_like(pz)
before = pd.DataFrame().reindex_like(pz)
after = pd.DataFrame().reindex_like(pz)

# %%
pup_all = pup_all.rename(columns = {0:'original'})
before = before.rename(columns = {0:'before'})
after = after.rename(columns = {0:'after'})
pup_all = pd.concat([pup_all, before, after],axis=1)
pup_all.head()
# Out:
#    original  before  after
# 0       NaN     NaN    NaN
# 1       NaN     NaN    NaN
# 2       NaN     NaN    NaN
# 3       NaN     NaN    NaN
# 4       NaN     NaN    NaN

# %%
for i in range(len(pup_zeros)):
    pup_all.original[i] = pup_zeros[i]
    pup_all.before[i] = pup_zeros[i] - 75
    pup_all.after[i] = pup_zeros[i] + 75
    

#group by sequence
#take list value by value find one not a number in sequence pull and store index of 150 samples before vlaue 
#then if next not is only one greater then last one if it is greater make that a new one

# %%
plt.plot(result["pupsize"][1140:1160])
#result["pupsize"][0:500]

# %%
pup_zeros
# Out:
# [350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372,
#  373,
#  1158,
#  1159,
#  1160,
#  1161,
#  1162,
#  1163,
#  1164,
#  1165,
#  1166,
#  1167,
#  1168,
#  1169,
#  1170,
#  1171,
#  1172,
#  1173,
#  1174,
#  1175,
#  1176,
#  1177,
#  1178,
#  1179,
#  1180,
#  1181,
#  1182,
#  1183,
#  1184,
#  1185,
#  1186,
#  1187,
#  1188,
#  1189,
#  1190,
#  1191,
#  1192,
#  1193,
#  1194,
#  1195,
#  1196,
#  1197,
#  1198,
#  2096,
#  2097,
#  2098,
#  2099,
#  2100,
#  2101,
#  2102,
#  2103,
#  2104,
#  2105,
#  2106,
#  2107,
#  2108,
#  2109,
#  2110,
#  2111,
#  2112,
#  2113,
#  2114,
#  2115,
#  2116,
#  2117,
#  2118,
#  2119,
#  2120,
#  2121,
#  3845,
#  3846,
#  3847,
#  3848,
#  3849,
#  3850,
#  3851,
#  3852,
#  3853,
#  3854,
#  3855,
#  3856,
#  3857,
#  3858,
#  3859,
#  3860,
#  3861,
#  3862,
#  3863,
#  3864,
#  3865,
#  3866,
#  3867,
#  3868,
#  3869,
#  3870,
#  3871,
#  3872,
#  3873,
#  5427,
#  5428,
#  5429,
#  5430,
#  5431,
#  5432,
#  5433,
#  5434,
#  5435,
#  5436,
#  5437,
#  5438,
#  5439,
#  5440,
#  5441,
#  5442,
#  5443,
#  5444,
#  5445,
#  5446,
#  5447,
#  5448,
#  5449,
#  5450,
#  5451,
#  5452,
#  5453,
#  5454,
#  5455,
#  5456,
#  5457,
#  5458,
#  5459,
#  7796,
#  7797,
#  7798,
#  7799,
#  7800,
#  7801,
#  8350,
#  8351,
#  8352,
#  8353,
#  8354,
#  8355,
#  8356,
#  9771,
#  9772,
#  9773,
#  9774,
#  9775,
#  9776,
#  9777,
#  9778,
#  9779,
#  9780,
#  9781,
#  9782,
#  9783,
#  9784,
#  9785,
#  9786,
#  9787,
#  9788,
#  9789,
#  9790,
#  9791,
#  9792,
#  9793,
#  9794,
#  9795,
#  9796,
#  9797,
#  9798,
#  10973,
#  10974,
#  10975,
#  10976,
#  10977,
#  10978,
#  10979,
#  10980,
#  10981,
#  10982,
#  10983,
#  10984,
#  10985,
#  10986,
#  10987,
#  10988,
#  10989,
#  10990,
#  10991,
#  10992,
#  10993,
#  10994,
#  10995,
#  10996,
#  10997,
#  10998,
#  10999,
#  11000,
#  11001,
#  12084,
#  12085,
#  12086,
#  12087,
#  12088,
#  12089,
#  12090,
#  12091,
#  12092,
#  12093,
#  12094,
#  12095,
#  12096,
#  12097,
#  12098,
#  12099,
#  12100,
#  12101,
#  12102,
#  12103,
#  12104,
#  12105,
#  12106,
#  12107,
#  12108,
#  12633,
#  12634,
#  12635,
#  12636,
#  12637,
#  12638,
#  12639,
#  12640,
#  12641,
#  12642,
#  12643,
#  12644,
#  12645,
#  12646,
#  12647,
#  12648,
#  12649,
#  12650,
#  12651,
#  12652,
#  12653,
#  12654,
#  12655,
#  12656,
#  12657,
#  12658,
#  12659,
#  12660,
#  12661,
#  12662,
#  12663,
#  12664,
#  13375,
#  13376,
#  13377,
#  13378,
#  13379,
#  13380,
#  13381,
#  13382,
#  13383,
#  13384,
#  13385,
#  13386,
#  13387,
#  13388,
#  13389,
#  13390,
#  13391,
#  13392,
#  13393,
#  13394,
#  13395,
#  13396,
#  13773,
#  13774,
#  13775,
#  13776,
#  13777,
#  13778,
#  13779,
#  13780,
#  13781,
#  13782,
#  13783,
#  13784,
#  13785,
#  13786,
#  13787,
#  13788,
#  13789,
#  13790,
#  13791,
#  13792,
#  13793,
#  13794,
#  13795,
#  13796,
#  13797,
#  13798,
#  13799,
#  13800,
#  13801,
#  13802,
#  13803,
#  13804,
#  13805,
#  13806,
#  13807,
#  13808,
#  13809,
#  13810,
#  13811,
#  13812,
#  13813,
#  13814,
#  13815,
#  13816,
#  13817,
#  13818,
#  13819,
#  13820,
#  13821,
#  13822,
#  15249,
#  15250,
#  15251,
#  15252,
#  15253,
#  15254,
#  15255,
#  15256,
#  16667,
#  16668,
#  16669,
#  16670,
#  16671,
#  16672,
#  16673,
#  16674,
#  16675,
#  16676,
#  16677,
#  16678,
#  16679,
#  16680,
#  16681,
#  16682,
#  16683,
#  16684,
#  16685,
#  16686,
#  16690,
#  16691,
#  16692,
#  16693,
#  16694,
#  17218,
#  17219,
#  17220,
#  17221,
#  17222,
#  17223,
#  17224,
#  17225,
#  17226,
#  17227,
#  17228,
#  17229,
#  17230,
#  17231,
#  17232,
#  18615,
#  18616,
#  18617,
#  18618,
#  18619,
#  18620,
#  18621,
#  18622,
#  18623,
#  18624,
#  20057,
#  20058,
#  20059,
#  20060,
#  20061,
#  20062,
#  20063,
#  20064,
#  20065,
#  20066,
#  20067,
#  20068,
#  20069,
#  20070,
#  20071,
#  20072,
#  20632,
#  20633,
#  20634,
#  20635,
#  20636,
#  20637,
#  20638,
#  20639,
#  20640,
#  20641,
#  20642,
#  20643,
#  20644,
#  20645,
#  20646,
#  20647,
#  20648,
#  20649,
#  20650,
#  20651,
#  20652,
#  20653,
#  20654,
#  20655,
#  20656,
#  20657,
#  20658,
#  20659,
#  20660,
#  20661,
#  20662,
#  20663,
#  20664,
#  20665,
#  20666,
#  20667,
#  20668,
#  20669,
#  20670,
#  20671,
#  20672,
#  20673,
#  20674,
#  20675,
#  20676,
#  20677,
#  20678,
#  20679,
#  20680,
#  20681,
#  20682,
#  20683,
#  21186,
#  21187,
#  21188,
#  21189,
#  21190,
#  21191,
#  21192,
#  21193,
#  21194,
#  21195,
#  21196,
#  21197,
#  21198,
#  21199,
#  21200,
#  21201,
#  21202,
#  21203,
#  21204,
#  21205,
#  21206,
#  21207,
#  21208,
#  21209,
#  21210,
#  21211,
#  21212,
#  21213,
#  21214,
#  21215,
#  21738,
#  21739,
#  21740,
#  21741,
#  21742,
#  21743,
#  21744,
#  21745,
#  21746,
#  21747,
#  21748,
#  21749,
#  21750,
#  21751,
#  21752,
#  21753,
#  21754,
#  21755,
#  21756,
#  21757,
#  21758,
#  21759,
#  21760,
#  21761,
#  21762,
#  22818,
#  22819,
#  22820,
#  22821,
#  22822,
#  24593,
#  24594,
#  24595,
#  24596,
#  24597,
#  24598,
#  24599,
#  24600,
#  24601,
#  24929,
#  24930,
#  24931,
#  24932,
#  24933,
#  24934,
#  24935,
#  24936,
#  24937,
#  24938,
#  24939,
#  24940,
#  24941,
#  24942,
#  24943,
#  24944,
#  24945,
#  24946,
#  24947,
#  24948,
#  24949,
#  24950,
#  24951,
#  24952,
#  24953,
#  24954,
#  24955,
#  24956,
#  24957,
#  24958,
#  24959,
#  24960,
#  24961,
#  24962,
#  24963,
#  24964,
#  25325,
#  25326,
#  25327,
#  25328,
#  25329,
#  25330,
#  25331,
#  25332,
#  25333,
#  25334,
#  25335,
#  25336,
#  25337,
#  25338,
#  25339,
#  25340,
#  25341,
#  25342,
#  25343,
#  25344,
#  25345,
#  25346,
#  25347,
#  25348,
#  25349,
#  25350,
#  26132,
#  26133,
#  26134,
#  26135,
#  26136,
#  26137,
#  26138,
#  26139,
#  26140,
#  26141,
#  26142,
#  26143,
#  26144,
#  26145,
#  26146,
#  26147,
#  26148,
#  26149,
#  26150,
#  26151,
#  26152,
#  27040,
#  27041,
#  27042,
#  27043,
#  27044,
#  27045,
#  27046,
#  27047,
#  27048,
#  27990,
#  27991,
#  27992,
#  27993,
#  27994,
#  27995,
#  27996,
#  27997,
#  27998,
#  27999,
#  28000,
#  28001,
#  28002,
#  28003,
#  28004,
#  28005,
#  28006,
#  28007,
#  28008,
#  28009,
#  28010,
#  28011,
#  28012,
#  28013,
#  28014,
#  28015,
#  28016,
#  28017,
#  29078,
#  29079,
#  29080,
#  29081,
#  29082,
#  29083,
#  29084,
#  29085,
#  29086,
#  29087,
#  29088,
#  29089,
#  29090,
#  29091,
#  29092,
#  29093,
#  29094,
#  29095,
#  29096,
#  29097,
#  29098,
#  29099,
#  29100,
#  29101,
#  29102,
#  29103,
#  29104,
#  30147,
#  30148,
#  30149,
#  30150,
#  30151,
#  30152,
#  30153,
#  30154,
#  30155,
#  30156,
#  30157,
#  30158,
#  30159,
#  30160,
#  30161,
#  30162,
#  30163,
#  30164,
#  30165,
#  30166,
#  30167,
#  30168,
#  30169,
#  30170,
#  30936,
#  30937,
#  30938,
#  30939,
#  30940,
#  30941,
#  30942,
#  30943,
#  30944,
#  30945,
#  30946,
#  30947,
#  30948,
#  30949,
#  30950,
#  30951,
#  30952,
#  30953,
#  30954,
#  30955,
#  30956,
#  30957,
#  30958,
#  30959,
#  30960,
#  30961,
#  31733,
#  31734,
#  31735,
#  31736,
#  31737,
#  31738,
#  31739,
#  31740,
#  31741,
#  31742,
#  31743,
#  31744,
#  31745,
#  31746,
#  31747,
#  31748,
#  31749,
#  31750,
#  31751,
#  31752,
#  31753,
#  31754,
#  31755,
#  31756,
#  31757,
#  31758,
#  31759,
#  31760,
#  32428,
#  32429,
#  32430,
#  32431,
#  32432,
#  32433,
#  32434,
#  32435,
#  32436,
#  32437,
#  32438,
#  32439,
#  32440,
#  32441,
#  32442,
#  32443,
#  32444,
#  32445,
#  32446,
#  32447,
#  32448,
#  32449,
#  32450,
#  32451,
#  32452,
#  32453,
#  32454,
#  32455,
#  32456,
#  32457,
#  32458,
#  32459,
#  32460,
#  33376,
#  33377,
#  33378,
#  33379,
#  33380,
#  33381,
#  33382,
#  33383,
#  33384,
#  33385,
#  33386,
#  33501,
#  33502,
#  33503,
#  33504,
#  33505,
#  33506,
#  33507,
#  33508,
#  33509,
#  33510,
#  33968,
#  33969,
#  33970,
#  33971,
#  33972,
#  33973,
#  33974,
#  33975,
#  33976,
#  33977,
#  33978,
#  33979,
#  33980,
#  33981,
#  33982,
#  33983,
#  33984,
#  33985,
#  33986,
#  33987,
#  33988,
#  33989,
#  33990,
#  33991,
#  33992,
#  33993,
#  33994,
#  33995,
#  33996,
#  33997,
#  33998,
#  33999,
#  34000,
#  34001,
#  34002,
#  34003,
#  34959,
#  34960,
#  34961,
#  34962,
#  34963,
#  34964,
#  34965,
#  34966,
#  34967,
#  34968,
#  34969,
#  34970,
#  34971,
#  34972,
#  34973,
#  34974,
#  34975,
#  34976,
#  34977,
#  34978,
#  34979,
#  34980,
#  34981,
#  34982,
#  34983,
#  34984,
#  34985,
#  34986,
#  34987,
#  35609,
#  35610,
#  35611,
#  35612,
#  35613,
#  35614,
#  35615,
#  35616,
#  35617,
#  35618,
#  35619,
#  35620,
#  35621,
#  35622,
#  35623,
#  35624,
#  35625,
#  35626,
#  35627,
#  35628,
#  35629,
#  35630,
#  35631,
#  35632,
#  35633,
#  35634,
#  35635,
#  35636,
#  36363,
#  36364,
#  36365,
#  36366,
#  36367,
#  36368,
#  36369,
#  36370,
#  36938,
#  36939,
#  36940,
#  36941,
#  36942,
#  36943,
#  36944,
#  36945,
#  36946,
#  36947,
#  36948,
#  36949,
#  36950,
#  36951,
#  36952,
#  36953,
#  37830,
#  37831,
#  37832,
#  37833,
#  37834,
#  37835,
#  37836,
#  37837,
#  37838,
#  37839,
#  37840,
#  37841,
#  37842,
#  37843,
#  37844,
#  37845,
#  37846,
#  37847,
#  37848,
#  37849,
#  37850,
#  37851,
#  37852,
#  37853,
#  37854,
#  37855,
#  37856,
#  37857,
#  37858,
#  37859,
#  37860,
#  37861,
#  37862,
#  37863,
#  37864,
#  37865,
#  38262,
#  38263,
#  38264,
#  38265,
#  38266,
#  38267,
#  38268,
#  38269,
#  38270,
#  38271,
#  38272,
#  38273,
#  38274,
#  38275,
#  38276,
#  38277,
#  38278,
#  38279,
#  38280,
#  38281,
#  38282,
#  ...]

# %%
pup_all.head()
# Out:
#    original  before  after
# 0     350.0   275.0  425.0
# 1     351.0   276.0  426.0
# 2     352.0   277.0  427.0
# 3     353.0   278.0  428.0
# 4     354.0   279.0  429.0

# %%
(pup_all.before[0])
# Out:
# 275.0

# %%
#result.pupsize[pup_all.before[0]] = None

# %%
for i in range(len(pup_all)):
    result.pupsize[pup_all.before[i],pup_all.after[i]] = None
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Applications/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
result.pupsize[275]
# Out:
# nan

# %%
result
# Out:
#           subject  unknown    nums  xcoor  ycoor  pupsize  timing  trial  \
# 0       PODC1.asc  unknown  583211  658.7    534    714.0     1.0      1
# 1       PODC1.asc  unknown  583213  659.8  534.1    714.0     3.0      1
# 2       PODC1.asc  unknown  583215  660.8  534.2    713.0     5.0      1
# 3       PODC1.asc  unknown  583217  661.6  534.4    713.0     7.0      1
# 4       PODC1.asc  unknown  583219  661.6  534.6    712.0     9.0      1
# 5       PODC1.asc  unknown  583221  661.5  534.8    712.0    11.0      1
# 6       PODC1.asc  unknown  583223  661.4  535.3    712.0    13.0      1
# 7       PODC1.asc  unknown  583225  660.6  535.8    712.0    15.0      1
# 8       PODC1.asc  unknown  583227  659.8  536.3    711.0    17.0      1
# 9       PODC1.asc  unknown  583229  658.9  536.8    711.0    19.0      1
# 10      PODC1.asc  unknown  583231    658  537.3    711.0    21.0      1
# 11      PODC1.asc  unknown  583233  657.1    538    711.0    23.0      1
# 12      PODC1.asc  unknown  583235  656.2  538.6    711.0    25.0      1
# 13      PODC1.asc  unknown  583237  655.1    539    710.0    27.0      1
# 14      PODC1.asc  unknown  583239  654.7  539.3    710.0    29.0      1
# 15      PODC1.asc  unknown  583241  654.1  539.4    709.0    31.0      1
# 16      PODC1.asc  unknown  583243  653.8    540    709.0    33.0      1
# 17      PODC1.asc  unknown  583245  653.5  540.6    708.0    35.0      1
# 18      PODC1.asc  unknown  583247  653.7  541.2    708.0    37.0      1
# 19      PODC1.asc  unknown  583249    654  541.7    708.0    39.0      1
# 20      PODC1.asc  unknown  583251  654.4  542.2    707.0    41.0      1
# 21      PODC1.asc  unknown  583253  654.8  542.8    707.0    43.0      1
# 22      PODC1.asc  unknown  583255  655.2  543.4    707.0    45.0      1
# 23      PODC1.asc  unknown  583257  655.6  543.5    706.0    47.0      1
# 24      PODC1.asc  unknown  583259  656.5  543.6    706.0    49.0      1
# 25      PODC1.asc  unknown  583261  657.4  543.7    706.0    51.0      1
# 26      PODC1.asc  unknown  583263  658.3  543.8    705.0    53.0      1
# 27      PODC1.asc  unknown  583265  659.2  543.8    705.0    55.0      1
# 28      PODC1.asc  unknown  583267    660  543.7    705.0    57.0      1
# 29      PODC1.asc  unknown  583269  660.8  543.6    704.0    59.0      1
# ...           ...      ...     ...    ...    ...      ...     ...    ...
# 133492  PODC1.asc  unknown  939497  699.7  501.8    409.0  8290.0     32
# 133493  PODC1.asc  unknown  939499  700.1  501.8    409.0  8292.0     32
# 133494  PODC1.asc  unknown  939501  700.6    502    409.0  8294.0     32
# 133495  PODC1.asc  unknown  939503    701  502.2    409.0  8296.0     32
# 133496  PODC1.asc  unknown  939505  701.5  502.4    409.0  8298.0     32
# 133497  PODC1.asc  unknown  939507  701.9  502.6    409.0  8300.0     32
# 133498  PODC1.asc  unknown  939509  702.4  502.8    409.0  8302.0     32
# 133499  PODC1.asc  unknown  939511  702.8    503    409.0  8304.0     32
# 133500  PODC1.asc  unknown  939513  703.2  503.1    409.0  8306.0     32
# 133501  PODC1.asc  unknown  939515  703.7  503.2    409.0  8308.0     32
# 133502  PODC1.asc  unknown  939517  704.1  503.2    409.0  8310.0     32
# 133503  PODC1.asc  unknown  939519    705  503.3    409.0  8312.0     32
# 133504  PODC1.asc  unknown  939521  705.8  503.4    409.0  8314.0     32
# 133505  PODC1.asc  unknown  939523  706.6  503.5    409.0  8316.0     32
# 133506  PODC1.asc  unknown  939525  707.3  503.5    409.0  8318.0     32
# 133507  PODC1.asc  unknown  939527    708  503.5    409.0  8320.0     32
# 133508  PODC1.asc  unknown  939529  708.5  503.2    409.0  8322.0     32
# 133509  PODC1.asc  unknown  939531  709.1  502.9    409.0  8324.0     32
# 133510  PODC1.asc  unknown  939533  709.7  502.5    409.0  8326.0     32
# 133511  PODC1.asc  unknown  939535  710.2  502.2    410.0  8328.0     32
# 133512  PODC1.asc  unknown  939537  710.8  501.7    410.0  8330.0     32
# 133513  PODC1.asc  unknown  939539  711.4  501.3    410.0  8332.0     32
# 133514  PODC1.asc  unknown  939541  711.9  500.8    410.0  8334.0     32
# 133515  PODC1.asc  unknown  939543  712.4  500.6    410.0     NaN     32
# 133516  PODC1.asc  unknown  939545  712.8  500.2    410.0  8338.0     32
# 133517  PODC1.asc  unknown  939547  712.9  499.8    410.0  8340.0     32
# 133518  PODC1.asc  unknown  939549  712.9  499.3    410.0  8342.0     32
# 133519  PODC1.asc  unknown  939551  712.7  498.9    411.0  8344.0     32
# 133520  PODC1.asc  unknown  939553  712.2  498.6    411.0  8346.0     32
# 133521  PODC1.asc  unknown  939555  711.7  498.5    411.0  8348.0     32
#
#        experiment tone1 tone2 condition       image  newtiming
# 0              PO  CGTT     F    dv.wav  new32.jpeg        2.0
# 1              PO  CGTT     F    dv.wav  new32.jpeg        4.0
# 2              PO  CGTT     F    dv.wav  new32.jpeg        6.0
# 3              PO  CGTT     F    dv.wav  new32.jpeg        8.0
# 4              PO  CGTT     F    dv.wav  new32.jpeg       10.0
# 5              PO  CGTT     F    dv.wav  new32.jpeg       12.0
# 6              PO  CGTT     F    dv.wav  new32.jpeg       14.0
# 7              PO  CGTT     F    dv.wav  new32.jpeg       16.0
# 8              PO  CGTT     F    dv.wav  new32.jpeg       18.0
# 9              PO  CGTT     F    dv.wav  new32.jpeg       20.0
# 10             PO  CGTT     F    dv.wav  new32.jpeg       22.0
# 11             PO  CGTT     F    dv.wav  new32.jpeg       24.0
# 12             PO  CGTT     F    dv.wav  new32.jpeg       26.0
# 13             PO  CGTT     F    dv.wav  new32.jpeg       28.0
# 14             PO  CGTT     F    dv.wav  new32.jpeg       30.0
# 15             PO  CGTT     F    dv.wav  new32.jpeg       32.0
# 16             PO  CGTT     F    dv.wav  new32.jpeg       34.0
# 17             PO  CGTT     F    dv.wav  new32.jpeg       36.0
# 18             PO  CGTT     F    dv.wav  new32.jpeg       38.0
# 19             PO  CGTT     F    dv.wav  new32.jpeg       40.0
# 20             PO  CGTT     F    dv.wav  new32.jpeg       42.0
# 21             PO  CGTT     F    dv.wav  new32.jpeg       44.0
# 22             PO  CGTT     F    dv.wav  new32.jpeg       46.0
# 23             PO  CGTT     F    dv.wav  new32.jpeg       48.0
# 24             PO  CGTT     F    dv.wav  new32.jpeg       50.0
# 25             PO  CGTT     F    dv.wav  new32.jpeg       52.0
# 26             PO  CGTT     F    dv.wav  new32.jpeg       54.0
# 27             PO  CGTT     F    dv.wav  new32.jpeg       56.0
# 28             PO  CGTT     F    dv.wav  new32.jpeg       58.0
# 29             PO  CGTT     F    dv.wav  new32.jpeg       60.0
# ...           ...   ...   ...       ...         ...        ...
# 133492         PO  CGTT     F    st.wav  new12.jpeg     8290.0
# 133493         PO  CGTT     F    st.wav  new12.jpeg     8292.0
# 133494         PO  CGTT     F    st.wav  new12.jpeg     8294.0
# 133495         PO  CGTT     F    st.wav  new12.jpeg     8296.0
# 133496         PO  CGTT     F    st.wav  new12.jpeg     8298.0
# 133497         PO  CGTT     F    st.wav  new12.jpeg     8300.0
# 133498         PO  CGTT     F    st.wav  new12.jpeg     8302.0
# 133499         PO  CGTT     F    st.wav  new12.jpeg     8304.0
# 133500         PO  CGTT     F    st.wav  new12.jpeg     8306.0
# 133501         PO  CGTT     F    st.wav  new12.jpeg     8308.0
# 133502         PO  CGTT     F    st.wav  new12.jpeg     8310.0
# 133503         PO  CGTT     F    st.wav  new12.jpeg     8312.0
# 133504         PO  CGTT     F    st.wav  new12.jpeg     8314.0
# 133505         PO  CGTT     F    st.wav  new12.jpeg     8316.0
# 133506         PO  CGTT     F    st.wav  new12.jpeg     8318.0
# 133507         PO  CGTT     F    st.wav  new12.jpeg     8320.0
# 133508         PO  CGTT     F    st.wav  new12.jpeg     8322.0
# 133509         PO  CGTT     F    st.wav  new12.jpeg     8324.0
# 133510         PO  CGTT     F    st.wav  new12.jpeg     8326.0
# 133511         PO  CGTT     F    st.wav  new12.jpeg     8328.0
# 133512         PO  CGTT     F    st.wav  new12.jpeg     8330.0
# 133513         PO  CGTT     F    st.wav  new12.jpeg     8332.0
# 133514         PO  CGTT     F    st.wav  new12.jpeg     8334.0
# 133515         PO  CGTT     F    st.wav  new12.jpeg        NaN
# 133516         PO  CGTT     F    st.wav  new12.jpeg     8338.0
# 133517         PO  CGTT     F    st.wav  new12.jpeg     8340.0
# 133518         PO  CGTT     F    st.wav  new12.jpeg     8342.0
# 133519         PO  CGTT     F    st.wav  new12.jpeg     8344.0
# 133520         PO  CGTT     F    st.wav  new12.jpeg     8346.0
# 133521         PO  CGTT     F    st.wav  new12.jpeg     8348.0
#
# [133522 rows x 14 columns]

# %%
result.head()
# Out:
#      subject  unknown    nums  xcoor  ycoor  pupsize  timing  trial  \
# 0  PODC1.asc  unknown  583211  658.7    534    714.0     1.0      1
# 1  PODC1.asc  unknown  583213  659.8  534.1    714.0     3.0      1
# 2  PODC1.asc  unknown  583215  660.8  534.2    713.0     5.0      1
# 3  PODC1.asc  unknown  583217  661.6  534.4    713.0     7.0      1
# 4  PODC1.asc  unknown  583219  661.6  534.6    712.0     9.0      1
#
#   experiment tone1 tone2 condition       image  newtiming
# 0         PO  CGTT     F    dv.wav  new32.jpeg        2.0
# 1         PO  CGTT     F    dv.wav  new32.jpeg        4.0
# 2         PO  CGTT     F    dv.wav  new32.jpeg        6.0
# 3         PO  CGTT     F    dv.wav  new32.jpeg        8.0
# 4         PO  CGTT     F    dv.wav  new32.jpeg       10.0

# %%
result.pupsize[375:400]
# Out:
# 375     58.0
# 376     58.0
# 377     58.0
# 378     59.0
# 379     69.0
# 380     81.0
# 381     97.0
# 382    115.0
# 383    136.0
# 384    160.0
# 385    201.0
# 386    235.0
# 387    271.0
# 388    304.0
# 389    343.0
# 390    381.0
# 391    420.0
# 392    442.0
# 393    467.0
# 394    485.0
# 395    509.0
# 396    527.0
# 397    546.0
# 398    561.0
# 399    575.0
# Name: pupsize, dtype: float64
